# %%
import pandas as pd

# %%
df = pd.read_csv("./kabaddiadda_auctiondata_FINAL.csv")

# %%
for index, row in df.iterrows():
    s = row['Player_Name']
    l = s.split('-')[:-1]
    
    # print(" ".join(l))
    # print(l.join(" "))
    # row['Player_Name'] = s.split()

    row['Player_Name'] = " ".join(l)

    print(row['Player_Name'])
# Out:
# pardeep narwal
# pardeep narwal
# pardeep narwal
# pardeep narwal
# pardeep narwal
# rahul chaudhari
# rahul chaudhari
# rahul chaudhari
# rahul chaudhari
# rahul chaudhari
# maninder singh
# maninder singh
# maninder singh
# maninder singh
# maninder singh
# deepak niwas hooda
# deepak niwas hooda
# deepak niwas hooda
# deepak niwas hooda
# deepak niwas hooda
# pawan kumar sehrawat
# pawan kumar sehrawat
# pawan kumar sehrawat
# pawan kumar sehrawat
# pawan kumar sehrawat
# naveen kumar
# naveen kumar
# naveen kumar
# naveen kumar
# naveen kumar
# sachin
# sachin
# sachin
# sachin
# sachin
# ajay thakur
# ajay thakur
# ajay thakur
# ajay thakur
# ajay thakur
# sandeep narwal
# sandeep narwal
# sandeep narwal
# sandeep narwal
# sandeep narwal
# manjeet chhillar
# manjeet chhillar
# manjeet chhillar
# manjeet chhillar
# manjeet chhillar
# vikas kandola
# vikas kandola
# vikas kandola
# vikas kandola
# vikas kandola
# po surjeet singh
# po surjeet singh
# po surjeet singh
# ...

# %%
df.to_csv("kabaddiadda_auctiondata_FINAL.csv")
