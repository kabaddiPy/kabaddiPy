# %%
import pandas as pd
import os

# %%
files = []
for file in os.listdir("."):
    if file.endswith("conv_touched.csv"):
        files.append(file)

print(len(files), files)

seas = "s8"
# Out:
# 12 ['U Mumba s8 conv_touched.csv', 'Jaipur Pink Panthers s8 conv_touched.csv', 'UP Yoddhas s8 conv_touched.csv', 'Dabang Delhi s8 conv_touched.csv', 'Puneri Paltan s8 conv_touched.csv', 'Gujarat Fortunegiants s8 conv_touched.csv', 'Patna Pirates s8 conv_touched.csv', 'Bengal Warriors s8 conv_touched.csv', 'Tamil Thalaivas s8 conv_touched.csv', 'Haryana Steeler s8 conv_touched.csv', 'Telugu Titans s8 conv_touched.csv', 'Bengaluru Bulls s8 conv_touched.csv']

# %%
for file in files:
    print(file.split(seas)[0].strip())
print(f"\nlen files: {len(files)}")
# Out:
# U Mumba
# Jaipur Pink Panthers
# UP Yoddhas
# Dabang Delhi
# Puneri Paltan
# Gujarat Fortunegiants
# Patna Pirates
# Bengal Warriors
# Tamil Thalaivas
# Haryana Steeler
# Telugu Titans
# Bengaluru Bulls
#
# len files: 12

# %%
df_list = []


for file in files:
    df = pd.read_csv(f"./{file}")
    df['team'] = file.split(seas)[0].strip()
    df['season'] = "PKL-S" + seas[-1]
    df_list.append(df)
    print(df.head())
    print("\n\n")
# Out:
#           Raider Name  Total Raids  Successful Raids Unnamed: 3     team  \
# 0      Abhishek Singh          363               149        41%  U Mumba
# 1      V. Ajith Kumar          291               130        45%  U Mumba
# 2              Shivam           57                26        46%  U Mumba
# 3       Ajinkya Kapre           46                12        26%  U Mumba
# 4  Mohsen Maghsoudlou           44                10        23%  U Mumba
#
#    season
# 0  PKL-S8
# 1  PKL-S8
# 2  PKL-S8
# 3  PKL-S8
# 4  PKL-S8
#
#
#
#      Raider Name  Total Raids  Successful Raids Unnamed: 3  \
# 0  Arjun Deshwal          421               226        54%
# 1   Deepak Hooda          281               105        37%
# 2    Nitin Rawal           47                 4         9%
# 3         Naveen           45                 9        20%
# 4  Sachin Narwal           30                13        43%
#
#                    team  season
# 0  Jaipur Pink Panthers  PKL-S8
# 1  Jaipur Pink Panthers  PKL-S8
# 2  Jaipur Pink Panthers  PKL-S8
# 3  Jaipur Pink Panthers  PKL-S8
# 4  Jaipur Pink Panthers  PKL-S8
#
#
#
#        Raider Name  Total Raids  Successful Raids Unnamed: 3        team  \
# 0    Surender Gill          355               143        40%  UP Yoddhas
# 1   Pardeep Narwal          349               144        41%  UP Yoddhas
# 2  Shrikant Jadhav          190                73        38%  UP Yoddhas
# 3      Rohit Tomar           36                16        44%  UP Yoddhas
# 4            Ankit           23                 5        22%  UP Yoddhas
#
#    season
# 0  PKL-S8
# 1  PKL-S8
# 2  PKL-S8
# 3  PKL-S8
# 4  PKL-S8
#
#
#
#       Raider Name  Total Raids  Successful Raids Unnamed: 3          team  \
# 0    Naveen Kumar          338               186        55%  Dabang Delhi
# 1    Vijay Jaglan          285               121        42%  Dabang Delhi
# 2      Ashu Malik          138                41        30%  Dabang Delhi
# 3   Neeraj Narwal           97                33        34%  Dabang Delhi
# 4  Sandeep Narwal           68                18        26%  Dabang Delhi
#
#    season
# 0  PKL-S8
# 1  PKL-S8
# 2  PKL-S8
# 3  PKL-S8
# 4  PKL-S8
#
#
#
#        Raider Name  Total Raids  Successful Raids Unnamed: 3           team  \
# 0   Asalam Inamdar          355               140        39%  Puneri Paltan
# 1      Mohit Goyat          305               139        46%  Puneri Paltan
# 2      Nitin Tomar          103                37        36%  Puneri Paltan
# 3    Pankaj Mohite           64                17        27%  Puneri Paltan
# 4  Rahul Chaudhari           35                10        29%  Puneri Paltan
#
#    season
# 0  PKL-S8
# 1  PKL-S8
# 2  PKL-S8
# 3  PKL-S8
# 4  PKL-S8
#
#
#
#        Raider Name  Total Raids  Successful Raids Unnamed: 3  \
# 0  Rakesh Sungroya          297               118        40%
# 1       Ajay Kumar          163                61        37%
# 2    Pardeep Kumar          148                55        37%
# 3    Rakesh Narwal          147                57        39%
# 4  Mahendra Rajput          119                47        39%
#
#                     team  season
# 0  Gujarat Fortunegiants  PKL-S8
# 1  Gujarat Fortunegiants  PKL-S8
# 2  Gujarat Fortunegiants  PKL-S8
# 3  Gujarat Fortunegiants  PKL-S8
# 4  Gujarat Fortunegiants  PKL-S8
#
#
#
#            Raider Name  Total Raids  Successful Raids Unnamed: 3  \
# 0        Sachin Tanwar          381               144        38%
# 1          Guman Singh          200                76        38%
# 2           Monu Goyat          165                62        38%
# 3  Prashanth Kumar Rai          163                73        45%
# 4          Monu Sandhu           31                 9        29%
#
#             team  season
# 0  Patna Pirates  PKL-S8
# 1  Patna Pirates  PKL-S8
# 2  Patna Pirates  PKL-S8
# 3  Patna Pirates  PKL-S8
# 4  Patna Pirates  PKL-S8
#
#
#
#           Raider Name  Total Raids  Successful Raids Unnamed: 3  \
# 0      Maninder Singh          401               197        49%
# 1  Esmaeil Nabibakhsh          185                67        36%
# 2        Sukesh Hegde          128                43        34%
# 3    Akash Pikalmunde           39                12        31%
# 4         Manoj Gowda           37                10        27%
#
#               team  season
# 0  Bengal Warriors  PKL-S8
# 1  Bengal Warriors  PKL-S8
# 2  Bengal Warriors  PKL-S8
# 3  Bengal Warriors  PKL-S8
# 4  Bengal Warriors  PKL-S8
#
#
#
#       Raider Name  Total Raids  Successful Raids Unnamed: 3             team  \
# 0         Manjeet          325               136        42%  Tamil Thalaivas
# 1   Ajinkya Pawar          213                83        39%  Tamil Thalaivas
# 2  Bhavani Rajput          111                33        30%  Tamil Thalaivas
# 3        Himanshu           78                30        38%  Tamil Thalaivas
# 4        Athul MS           73                21        29%  Tamil Thalaivas
#
#    season
# 0  PKL-S8
# 1  PKL-S8
# 2  PKL-S8
# 3  PKL-S8
# 4  PKL-S8
#
#
#
#       Raider Name  Total Raids  Successful Raids Unnamed: 3             team  \
# 0  Vikash Kandola          356               147        41%  Haryana Steeler
# 1           Meetu          192                67        35%  Haryana Steeler
# 2     Rohit Gulia          113                43        38%  Haryana Steeler
# 3          Ashish          102                43        42%  Haryana Steeler
# 4           Vinay           96                48        50%  Haryana Steeler
#
#    season
# 0  PKL-S8
# 1  PKL-S8
# 2  PKL-S8
# 3  PKL-S8
# 4  PKL-S8
#
#
#
#      Raider Name  Total Raids  Successful Raids Unnamed: 3           team  \
# 0  Ankit Beniwal          238                87        37%  Telugu Titans
# 1        Rajnish          190                86        45%  Telugu Titans
# 2       Adarsh T          147                55        37%  Telugu Titans
# 3     Galla Raju           92                31        34%  Telugu Titans
# 4   Rakesh Gowda           83                28        34%  Telugu Titans
#
#    season
# 0  PKL-S8
# 1  PKL-S8
# 2  PKL-S8
# 3  PKL-S8
# 4  PKL-S8
#
#
#
#        Raider Name  Total Raids  Successful Raids Unnamed: 3             team  \
# 0   Pawan Sehrawat          478               250        52%  Bengaluru Bulls
# 1    Bharat Naresh          196                98        50%  Bengaluru Bulls
# 2  Chandran Ranjit          185                61        33%  Bengaluru Bulls
# 3    Deepak Narwal           45                12        27%  Bengaluru Bulls
# 4          More GB           40                 3         8%  Bengaluru Bulls
#
#    season
# 0  PKL-S8
# 1  PKL-S8
# 2  PKL-S8
# 3  PKL-S8
# 4  PKL-S8

# %%
merged_df = pd.concat(df_list, axis=0, ignore_index=True)

# %%
merged_df
# Out:
#                   Raider Name  Total Raids  Successful Raids Unnamed: 3  \
# 0              Abhishek Singh          363               149        41%
# 1              V. Ajith Kumar          291               130        45%
# 2                      Shivam           57                26        46%
# 3               Ajinkya Kapre           46                12        26%
# 4          Mohsen Maghsoudlou           44                10        23%
# ..                        ...          ...               ...        ...
# 158            Mahender Singh           12                 0         0%
# 159            Mohit Sehrawat           11                 0         0%
# 160  Abolfazl Maghsodloumah..            6                 2        33%
# 161                      Aman            3                 1        33%
# 162            Saurabh Nandal            2                 0         0%
#
#                 team  season
# 0            U Mumba  PKL-S8
# 1            U Mumba  PKL-S8
# 2            U Mumba  PKL-S8
# 3            U Mumba  PKL-S8
# 4            U Mumba  PKL-S8
# ..               ...     ...
# 158  Bengaluru Bulls  PKL-S8
# 159  Bengaluru Bulls  PKL-S8
# 160  Bengaluru Bulls  PKL-S8
# 161  Bengaluru Bulls  PKL-S8
# 162  Bengaluru Bulls  PKL-S8
#
# [163 rows x 6 columns]

# %%
cols = merged_df.columns.tolist()
# cols = ['SuccessfulRaids_Percentage' if x=="Unnamed: 3" else x for x in cols]
print(cols[-2:] + cols[:-2])

cols = cols[-2:] + cols[:-2]

merged_df = merged_df[cols]
# Out:
# ['team', 'season', 'Raider Name', 'Total Raids', 'Successful Raids', 'Unnamed: 3']

# %%
merged_df.to_csv("__s6_merged.csv", index=False)
