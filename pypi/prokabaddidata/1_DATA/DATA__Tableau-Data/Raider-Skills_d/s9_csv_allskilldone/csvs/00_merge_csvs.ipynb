# %%
import pandas as pd
import os

# %%
files = []
for file in os.listdir("."):
    if file.endswith("conv.csv"):
        files.append(file)

print(len(files), files)

seas = "s9"
# Out:
# 12 ['Jaipur Pink Panthers s9 conv.csv', 'Haryana Steelers s9 conv.csv', 'Tamil Thailaivas s9 conv.csv', 'Dabang Delhi s9 conv.csv', 'Puneri Paltan s9 conv.csv', 'U Mumba s9 conv.csv', 'Patna Pirates s9 conv.csv', 'Bengaluru Bulls s9 conv.csv', 'Bengal Warriors s9 conv.csv', 'UP Yoddha s9 conv.csv', 'Gujarat Fortunegiants s9 conv.csv', 'Telugu Titans  s9 conv.csv']

# %%
for file in files:
    print(file.split(seas)[0].strip())
print(f"\nlen files: {len(files)}")
# Out:
# Jaipur Pink Panthers
# Haryana Steelers
# Tamil Thailaivas
# Dabang Delhi
# Puneri Paltan
# U Mumba
# Patna Pirates
# Bengaluru Bulls
# Bengal Warriors
# UP Yoddha
# Gujarat Fortunegiants
# Telugu Titans
#
# len files: 12

# %%
df_list = []


for file in files:
    df = pd.read_csv(f"./{file}")
    df['team'] = file.split(seas)[0].strip()
    df['season'] = "PKL-S" + seas[-1]
    df_list.append(df)
    print(df.head())
    print("\n\n")
# Out:
#        Raider Name  Total Raids  Successful Raids Unnamed: 3  \
# 0    Arjun Deshwal          449               241        54%
# 1    Ajith V Kumar          182                72        40%
# 2  Rahul Chaudhari          180                58        32%
# 3   Bhavani Rajput           77                28        36%
# 4      Sunil Kumar           29                 1         3%
#
#                    team  season
# 0  Jaipur Pink Panthers  PKL-S9
# 1  Jaipur Pink Panthers  PKL-S9
# 2  Jaipur Pink Panthers  PKL-S9
# 3  Jaipur Pink Panthers  PKL-S9
# 4  Jaipur Pink Panthers  PKL-S9
#
#
#
#       Raider Name  Total Raids  Successful Raids Unnamed: 3              team  \
# 0  Meetu Mahender          318               116        36%  Haryana Steelers
# 1  Manjeet Dahiya          185                81        44%  Haryana Steelers
# 2   Rakesh Narwal          110                33        30%  Haryana Steelers
# 3         Manjeet           89                39        44%  Haryana Steelers
# 4     K Prapanjan           66                30        45%  Haryana Steelers
#
#    season
# 0  PKL-S9
# 1  PKL-S9
# 2  PKL-S9
# 3  PKL-S9
# 4  PKL-S9
#
#
#
#            Raider Name  Total Raids  Successful Raids Unnamed: 3  \
# 0             Narender          371               184        50%
# 1  Ajinkya Ashok Pawar          282                90        32%
# 2             Himanshu          138                27        20%
# 3       Himanshu Singh           95                27        28%
# 4          Visvanath V           34                10        29%
#
#                team  season
# 0  Tamil Thailaivas  PKL-S9
# 1  Tamil Thailaivas  PKL-S9
# 2  Tamil Thailaivas  PKL-S9
# 3  Tamil Thailaivas  PKL-S9
# 4  Tamil Thailaivas  PKL-S9
#
#
#
#      Raider Name  Total Raids  Successful Raids Unnamed: 3          team  \
# 0   Naveen Kumar          439               223        51%  Dabang Delhi
# 1     Ashu Malik          277               109        39%  Dabang Delhi
# 2   Vijay Jaglan          114                53        46%  Dabang Delhi
# 3        Manjeet          105                41        39%  Dabang Delhi
# 4  Ashish Narwal           20                 6        30%  Dabang Delhi
#
#    season
# 0  PKL-S9
# 1  PKL-S9
# 2  PKL-S9
# 3  PKL-S9
# 4  PKL-S9
#
#
#
#                Raider Name  Total Raids  Successful Raids Unnamed: 3  \
# 0    Aslam Mustafa Inamdar          268               118        44%
# 1              Mohit Goyat          257               100        39%
# 2     Akash Santosh Shinde          195               101        52%
# 3            Pankaj Mohite          110                48        44%
# 4  Mohammad Esmaeil Nabi..           62                11        18%
#
#             team  season
# 0  Puneri Paltan  PKL-S9
# 1  Puneri Paltan  PKL-S9
# 2  Puneri Paltan  PKL-S9
# 3  Puneri Paltan  PKL-S9
# 4  Puneri Paltan  PKL-S9
#
#
#
#         Raider Name  Total Raids  Successful Raids Unnamed: 3     team  season
# 0       Guman Singh          279               107        38%  U Mumba  PKL-S9
# 1    Ashish (Bubla)          195                63        32%  U Mumba  PKL-S9
# 2       Jai Bhagwan          163                52        32%  U Mumba  PKL-S9
# 3  Heidarali Ekrami           64                21        33%  U Mumba  PKL-S9
# 4            Ashish           64                20        31%  U Mumba  PKL-S9
#
#
#
#      Raider Name  Total Raids  Successful Raids Unnamed: 3           team  \
# 0    Rohit Gulia          293               122        42%  Patna Pirates
# 1  Sachin Tanwar          272               109        40%  Patna Pirates
# 2         Sachin          105                41        39%  Patna Pirates
# 3    Monu Sandhu           96                12        13%  Patna Pirates
# 4     Anuj Kumar           37                 7        19%  Patna Pirates
#
#    season
# 0  PKL-S9
# 1  PKL-S9
# 2  PKL-S9
# 3  PKL-S9
# 4  PKL-S9
#
#
#
#        Raider Name  Total Raids  Successful Raids Unnamed: 3             team  \
# 0    Bharat Naresh          361               211        58%  Bengaluru Bulls
# 1   Vikash Kandola          306               106        35%  Bengaluru Bulls
# 2    Neeraj Narwal          193                61        32%  Bengaluru Bulls
# 3    Sachin Narwal           60                27        45%  Bengaluru Bulls
# 4  Vikash Khandola           18                10        56%  Bengaluru Bulls
#
#    season
# 0  PKL-S9
# 1  PKL-S9
# 2  PKL-S9
# 3  PKL-S9
# 4  PKL-S9
#
#
#
#        Raider Name  Total Raids  Successful Raids Unnamed: 3             team  \
# 0   Maninder Singh          363               186        51%  Bengal Warriors
# 1  Shrikant Jadhav          250                99        40%  Bengal Warriors
# 2     Deepak Hooda          124                40        32%  Bengal Warriors
# 3      Manoj Gowda           56                20        36%  Bengal Warriors
# 4    Ajinkya Kapre           30                 6        20%  Bengal Warriors
#
#    season
# 0  PKL-S9
# 1  PKL-S9
# 2  PKL-S9
# 3  PKL-S9
# 4  PKL-S9
#
#
#
#       Raider Name  Total Raids  Successful Raids Unnamed: 3       team  season
# 0  Pardeep Narwal          355               162        46%  UP Yoddha  PKL-S9
# 1   Surender Gill          206               101        49%  UP Yoddha  PKL-S9
# 2     Rohit Tomar          166                57        34%  UP Yoddha  PKL-S9
# 3      Anil Kumar           38                11        29%  UP Yoddha  PKL-S9
# 4  Sandeep Narwal           35                 8        23%  UP Yoddha  PKL-S9
#
#
#
#               Raider Name  Total Raids  Successful Raids Unnamed: 3  \
# 0         Rakesh Sangroya          271               111        41%
# 1          Parteek Dhaiya          240               126        53%
# 2         Chandran Ranjit          162                75        46%
# 3                    Sonu           80                30        38%
# 4  Mahendra Ganesh Rajput           67                39        58%
#
#                     team  season
# 0  Gujarat Fortunegiants  PKL-S9
# 1  Gujarat Fortunegiants  PKL-S9
# 2  Gujarat Fortunegiants  PKL-S9
# 3  Gujarat Fortunegiants  PKL-S9
# 4  Gujarat Fortunegiants  PKL-S9
#
#
#
#                 Raider Name  Total Raids  Successful Raids Unnamed: 3  \
# 0    Siddharth Sirish Desai          224               114        51%
# 1            Abhishek Singh          188                50        27%
# 2  Mohsen Maghsoudlou Jaf..          111                20        18%
# 3                  Adarsh T           99                30        30%
# 4                     Vinay           95                28        29%
#
#             team  season
# 0  Telugu Titans  PKL-S9
# 1  Telugu Titans  PKL-S9
# 2  Telugu Titans  PKL-S9
# 3  Telugu Titans  PKL-S9
# 4  Telugu Titans  PKL-S9

# %%
merged_df = pd.concat(df_list, axis=0, ignore_index=True)

# %%
merged_df
# Out:
#            Raider Name  Total Raids  Successful Raids Unnamed: 3  \
# 0        Arjun Deshwal          449               241        54%
# 1        Ajith V Kumar          182                72        40%
# 2      Rahul Chaudhari          180                58        32%
# 3       Bhavani Rajput           77                28        36%
# 4          Sunil Kumar           29                 1         3%
# ..                 ...          ...               ...        ...
# 181              Ankit            3                 2        67%
# 182        Mohit Pahal            2                 0         0%
# 183  Palla Ramakrishna            1                 0         0%
# 184              Nitin            1                 0         0%
# 185  Muhammed Shihas S            1                 0         0%
#
#                      team  season
# 0    Jaipur Pink Panthers  PKL-S9
# 1    Jaipur Pink Panthers  PKL-S9
# 2    Jaipur Pink Panthers  PKL-S9
# 3    Jaipur Pink Panthers  PKL-S9
# 4    Jaipur Pink Panthers  PKL-S9
# ..                    ...     ...
# 181         Telugu Titans  PKL-S9
# 182         Telugu Titans  PKL-S9
# 183         Telugu Titans  PKL-S9
# 184         Telugu Titans  PKL-S9
# 185         Telugu Titans  PKL-S9
#
# [186 rows x 6 columns]

# %%
cols = merged_df.columns.tolist()
# cols = ['SuccessfulRaids_Percentage' if x=="Unnamed: 3" else x for x in cols]
print(cols[-2:] + cols[:-2])

cols = cols[-2:] + cols[:-2]

merged_df = merged_df[cols]
# Out:
# ['team', 'season', 'Raider Name', 'Total Raids', 'Successful Raids', 'Unnamed: 3']

# %%
merged_df.to_csv("__s9_merged.csv", index=False)
