# %%
import pandas as pd
import os

# %%
files = []
for file in os.listdir("."):
    if file.endswith("conv.csv"):
        files.append(file)

len(files), files
# Out:
# (12,
#  ['Patna Pirates s6 conv.csv',
#   'Bengaluru Bulls s6 conv.csv',
#   'Bengal Warriors s6 conv.csv',
#   'UP Yoddha s6 conv.csv',
#   'Gujarat Fortunegiants s6 conv.csv',
#   'U Mumba s6 conv.csv',
#   'Haryana Steelers s6 conv.csv',
#   'Tamil Thailaivas s6 conv.csv',
#   'Dabang Delhi s6 conv.csv',
#   'Puneri Paltan s6 conv.csv',
#   'Telugu Titans s6 conv.csv',
#   'Jaipur Pink Panthers s6 conv.csv'])

# %%
for file in files:
    print(file.split("s6")[0].strip())
print(f"\nlen files: {len(files)}")
# Out:
# Patna Pirates
# Bengaluru Bulls
# Bengal Warriors
# UP Yoddha
# Gujarat Fortunegiants
# U Mumba
# Haryana Steelers
# Tamil Thailaivas
# Dabang Delhi
# Puneri Paltan
# Telugu Titans
# Jaipur Pink Panthers
#
# len files: 12

# %%
df_list = []
seas = "s6"

for file in files:
    df = pd.read_csv(f"./{file}")
    df['team'] = file.split(seas)[0].strip()
    df['season'] = "PKL-S" + seas[-1]
    df_list.append(df)
    print(df.head())
    print("\n\n")
# Out:
#       Raider Name  Total Raids  Successful Raids Unnamed: 3           team  \
# 0  Pardeep Narwal          391               192        49%  Patna Pirates
# 1         Manjeet          189                78        41%  Patna Pirates
# 2   Deepak Narwal          140                58        41%  Patna Pirates
# 3           Vijay          111                50        45%  Patna Pirates
# 4    Vikas Jaglan           42                13        31%  Patna Pirates
#
#    season
# 0  PKL-S6
# 1  PKL-S6
# 2  PKL-S6
# 3  PKL-S6
# 4  PKL-S6
#
#
#
#        Raider Name  Total Raids  Successful Raids Unnamed: 3             team  \
# 0   Pawan Sehrawat          375               214        57%  Bengaluru Bulls
# 1      Rohit Kumar          341               134        39%  Bengaluru Bulls
# 2  Kashiling Adake          164                51        31%  Bengaluru Bulls
# 3      Harish Naik           29                14        48%  Bengaluru Bulls
# 4      Sumit Singh           27                 7        26%  Bengaluru Bulls
#
#    season
# 0  PKL-S6
# 1  PKL-S6
# 2  PKL-S6
# 3  PKL-S6
# 4  PKL-S6
#
#
#
#                Raider Name  Total Raids  Successful Raids Unnamed: 3  \
# 0           Maninder Singh          377               163        43%
# 1             Jang Kun Lee          171                63        37%
# 2              Mahesh Goud           92                27        29%
# 3  Ravindra Ramesh Kumaw..           91                30        33%
# 4                Ran Singh           72                23        32%
#
#               team  season
# 0  Bengal Warriors  PKL-S6
# 1  Bengal Warriors  PKL-S6
# 2  Bengal Warriors  PKL-S6
# 3  Bengal Warriors  PKL-S6
# 4  Bengal Warriors  PKL-S6
#
#
#
#            Raider Name  Total Raids  Successful Raids Unnamed: 3       team  \
# 0      Shrikant Jadhav          332               112        34%  UP Yoddha
# 1     Rishank Devadiga          262                84        32%  UP Yoddha
# 2  Prashanth Kumar Rai          262               115        44%  UP Yoddha
# 3         Sachin Kumar           89                21        24%  UP Yoddha
# 4           Azad Singh           48                14        29%  UP Yoddha
#
#    season
# 0  PKL-S6
# 1  PKL-S6
# 2  PKL-S6
# 3  PKL-S6
# 4  PKL-S6
#
#
#
#        Raider Name  Total Raids  Successful Raids Unnamed: 3  \
# 0           Sachin          366               166        45%
# 1     K. Prapanjan          255                97        38%
# 2      Rohit Gulia          152                50        33%
# 3       Ajay Kumar           88                26        30%
# 4  Mahendra Rajput           66                19        29%
#
#                     team  season
# 0  Gujarat Fortunegiants  PKL-S6
# 1  Gujarat Fortunegiants  PKL-S6
# 2  Gujarat Fortunegiants  PKL-S6
# 3  Gujarat Fortunegiants  PKL-S6
# 4  Gujarat Fortunegiants  PKL-S6
#
#
#
#                 Raider Name  Total Raids  Successful Raids Unnamed: 3  \
# 0    Siddharth Sirish Desai          321               174        54%
# 1             Rohit Baliyan          188                82        44%
# 2            Darshan Kadian          141                40        28%
# 3            Abhishek Singh          117                38        32%
# 4  Abolfazl Maghsodloumah..           77                19        25%
#
#       team  season
# 0  U Mumba  PKL-S6
# 1  U Mumba  PKL-S6
# 2  U Mumba  PKL-S6
# 3  U Mumba  PKL-S6
# 4  U Mumba  PKL-S6
#
#
#
#             Raider Name  Total Raids  Successful Raids Unnamed: 3  \
# 0       Vikash Khandola          347               141        41%
# 1            Monu Goyat          301               131        44%
# 2                Naveen          193                75        39%
# 3      Mayur Shivtarkar           36                 1         3%
# 4  Anand Surendra Tomar           20                 7        35%
#
#                team  season
# 0  Haryana Steelers  PKL-S6
# 1  Haryana Steelers  PKL-S6
# 2  Haryana Steelers  PKL-S6
# 3  Haryana Steelers  PKL-S6
# 4  Haryana Steelers  PKL-S6
#
#
#
#      Raider Name  Total Raids  Successful Raids Unnamed: 3              team  \
# 0    Ajay Thakur          388               180        46%  Tamil Thailaivas
# 1   Sukesh Hegde          176                50        28%  Tamil Thailaivas
# 2   Jasvir Singh          117                34        29%  Tamil Thailaivas
# 3       Athul MS          105                46        44%  Tamil Thailaivas
# 4  Surjeet Singh           45                10        22%  Tamil Thailaivas
#
#    season
# 0  PKL-S6
# 1  PKL-S6
# 2  PKL-S6
# 3  PKL-S6
# 4  PKL-S6
#
#
#
#        Raider Name  Total Raids  Successful Raids Unnamed: 3          team  \
# 0  Chandran Ranjit          316               133        42%  Dabang Delhi
# 1     Naveen Kumar          307               147        48%  Dabang Delhi
# 2     Meraj Sheykh          213                72        34%  Dabang Delhi
# 3      Pawan Kumar           90                36        40%  Dabang Delhi
# 4    Shabeer Bappu           26                 6        23%  Dabang Delhi
#
#    season
# 0  PKL-S6
# 1  PKL-S6
# 2  PKL-S6
# 3  PKL-S6
# 4  PKL-S6
#
#
#
#            Raider Name  Total Raids  Successful Raids Unnamed: 3  \
# 0          Nitin Tomar          192                90        47%
# 1             More G B          173                60        35%
# 2                 Monu          123                39        32%
# 3        Akshay Jadhav          108                26        24%
# 4  Deepak Kumar Dahiya           88                26        30%
#
#             team  season
# 0  Puneri Paltan  PKL-S6
# 1  Puneri Paltan  PKL-S6
# 2  Puneri Paltan  PKL-S6
# 3  Puneri Paltan  PKL-S6
# 4  Puneri Paltan  PKL-S6
#
#
#
#           Raider Name  Total Raids  Successful Raids Unnamed: 3  \
# 0     Rahul Chaudhari          350               139        40%
# 1      Nilesh Salunke          201                61        30%
# 2  Mohsen Maghsoudlou          111                26        23%
# 3  Farhad Milaghardan           61                17        28%
# 4     Vishal Bhardwaj           40                 0         0%
#
#             team  season
# 0  Telugu Titans  PKL-S6
# 1  Telugu Titans  PKL-S6
# 2  Telugu Titans  PKL-S6
# 3  Telugu Titans  PKL-S6
# 4  Telugu Titans  PKL-S6
#
#
#
#            Raider Name  Total Raids  Successful Raids Unnamed: 3  \
# 0         Deepak Hooda          367               164        45%
# 1  Ajinkya Ashok Pawar          163                59        36%
# 2           Anup Kumar          127                30        24%
# 3          Selvamani K           82                27        33%
# 4          Nitin Rawal           57                20        35%
#
#                    team  season
# 0  Jaipur Pink Panthers  PKL-S6
# 1  Jaipur Pink Panthers  PKL-S6
# 2  Jaipur Pink Panthers  PKL-S6
# 3  Jaipur Pink Panthers  PKL-S6
# 4  Jaipur Pink Panthers  PKL-S6

# %%
merged_df = pd.concat(df_list, axis=0, ignore_index=True)

# %%
merged_df
# Out:
#             Raider Name  Total Raids  Successful Raids Unnamed: 3  \
# 0        Pardeep Narwal          391               192        49%
# 1               Manjeet          189                78        41%
# 2         Deepak Narwal          140                58        41%
# 3                 Vijay          111                50        45%
# 4          Vikas Jaglan           42                13        31%
# ..                  ...          ...               ...        ...
# 162  Gangadhari Mallesh            9                 1        11%
# 163     David Mosambayi            6                 1        17%
# 164      Mohit Chhillar            4                 0         0%
# 165    Santhapanaselvam            1                 0         0%
# 166       Sandeep Dhull            1                 0         0%
#
#                      team  season
# 0           Patna Pirates  PKL-S6
# 1           Patna Pirates  PKL-S6
# 2           Patna Pirates  PKL-S6
# 3           Patna Pirates  PKL-S6
# 4           Patna Pirates  PKL-S6
# ..                    ...     ...
# 162  Jaipur Pink Panthers  PKL-S6
# 163  Jaipur Pink Panthers  PKL-S6
# 164  Jaipur Pink Panthers  PKL-S6
# 165  Jaipur Pink Panthers  PKL-S6
# 166  Jaipur Pink Panthers  PKL-S6
#
# [167 rows x 6 columns]

# %%
cols = merged_df.columns.tolist()
# cols = ['SuccessfulRaids_Percentage' if x=="Unnamed: 3" else x for x in cols]
print(cols[-2:] + cols[:-2])

cols = cols[-2:] + cols[:-2]

merged_df = merged_df[cols]
# Out:
# ['team', 'season', 'Raider Name', 'Total Raids', 'Successful Raids', 'Unnamed: 3']

# %%
merged_df.to_csv("__s6_merged.csv", index=False)
