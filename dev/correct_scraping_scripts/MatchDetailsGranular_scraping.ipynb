# %%
print("hello")
# Out:
# hello

# %%
import json
import re

# %%
# Path to your local HTML file
file_path = r"C:\Users\KIIT\Downloads\season7.html"

# Read the HTML file
with open(file_path, 'r', encoding='utf-8') as file:
    html_content = file.read()

# Define the regex pattern
pattern = r'<a href="(/matchcentre/\d+-scorecard)"'

# Find all matches
matches7 = re.findall(pattern, html_content)

# %%
matches7
# Out:
# ['/matchcentre/1821-scorecard',
#  '/matchcentre/1820-scorecard',
#  '/matchcentre/1819-scorecard',
#  '/matchcentre/1818-scorecard',
#  '/matchcentre/1817-scorecard',
#  '/matchcentre/1816-scorecard',
#  '/matchcentre/1815-scorecard',
#  '/matchcentre/1814-scorecard',
#  '/matchcentre/1813-scorecard',
#  '/matchcentre/1812-scorecard',
#  '/matchcentre/1811-scorecard',
#  '/matchcentre/1810-scorecard',
#  '/matchcentre/1809-scorecard',
#  '/matchcentre/1808-scorecard',
#  '/matchcentre/1807-scorecard',
#  '/matchcentre/1806-scorecard',
#  '/matchcentre/1805-scorecard',
#  '/matchcentre/1804-scorecard',
#  '/matchcentre/1803-scorecard',
#  '/matchcentre/1802-scorecard',
#  '/matchcentre/1801-scorecard',
#  '/matchcentre/1800-scorecard',
#  '/matchcentre/1799-scorecard',
#  '/matchcentre/1798-scorecard',
#  '/matchcentre/1797-scorecard',
#  '/matchcentre/1796-scorecard',
#  '/matchcentre/1795-scorecard',
#  '/matchcentre/1794-scorecard',
#  '/matchcentre/1793-scorecard',
# ...

# %%
# Path to your local HTML file
file_path = r"C:\Users\KIIT\Downloads\season6.html"

# Read the HTML file
with open(file_path, 'r', encoding='utf-8') as file:
    html_content = file.read()

# Define the regex pattern
pattern = r'<a href="(/matchcentre/\d+-scorecard)"'

# Find all matches
matches6 = re.findall(pattern, html_content)

# # Print the extracted links
# for link in matches:
#     print(f"https://example.com{link}")

# %%
matches6
# Out:
# ['/matchcentre/762-scorecard',
#  '/matchcentre/761-scorecard',
#  '/matchcentre/760-scorecard',
#  '/matchcentre/759-scorecard',
#  '/matchcentre/758-scorecard',
#  '/matchcentre/757-scorecard',
#  '/matchcentre/756-scorecard',
#  '/matchcentre/755-scorecard',
#  '/matchcentre/754-scorecard',
#  '/matchcentre/753-scorecard',
#  '/matchcentre/752-scorecard',
#  '/matchcentre/751-scorecard',
#  '/matchcentre/746-scorecard',
#  '/matchcentre/750-scorecard',
#  '/matchcentre/748-scorecard',
#  '/matchcentre/747-scorecard',
#  '/matchcentre/749-scorecard',
#  '/matchcentre/745-scorecard',
#  '/matchcentre/744-scorecard',
#  '/matchcentre/743-scorecard',
#  '/matchcentre/742-scorecard',
#  '/matchcentre/741-scorecard',
#  '/matchcentre/740-scorecard',
#  '/matchcentre/739-scorecard',
#  '/matchcentre/738-scorecard',
#  '/matchcentre/737-scorecard',
#  '/matchcentre/736-scorecard',
#  '/matchcentre/735-scorecard',
#  '/matchcentre/734-scorecard',
#  '/matchcentre/733-scorecard',
# ...

# %%
# Path to local HTML file
file_path = r"C:\Users\KIIT\Downloads\season5.html"

# Read the HTML file
with open(file_path, 'r', encoding='utf-8') as file:
    html_content = file.read()

# Define the regex pattern
pattern = r'<a href="(/matchcentre/\d+-scorecard)"'

# Find all matches
matches5 = re.findall(pattern, html_content)

# %%
matches5
# Out:
# ['/matchcentre/423-scorecard',
#  '/matchcentre/422-scorecard',
#  '/matchcentre/421-scorecard',
#  '/matchcentre/420-scorecard',
#  '/matchcentre/419-scorecard',
#  '/matchcentre/418-scorecard',
#  '/matchcentre/417-scorecard',
#  '/matchcentre/416-scorecard',
#  '/matchcentre/415-scorecard',
#  '/matchcentre/414-scorecard',
#  '/matchcentre/413-scorecard',
#  '/matchcentre/336-scorecard',
#  '/matchcentre/412-scorecard',
#  '/matchcentre/411-scorecard',
#  '/matchcentre/410-scorecard',
#  '/matchcentre/409-scorecard',
#  '/matchcentre/408-scorecard',
#  '/matchcentre/407-scorecard',
#  '/matchcentre/406-scorecard',
#  '/matchcentre/405-scorecard',
#  '/matchcentre/404-scorecard',
#  '/matchcentre/403-scorecard',
#  '/matchcentre/402-scorecard',
#  '/matchcentre/401-scorecard',
#  '/matchcentre/400-scorecard',
#  '/matchcentre/399-scorecard',
#  '/matchcentre/398-scorecard',
#  '/matchcentre/397-scorecard',
#  '/matchcentre/396-scorecard',
#  '/matchcentre/395-scorecard',
# ...

# %%
# Path to local HTML file
file_path = r"C:\Users\KIIT\Downloads\season4.html"

# Read the HTML file
with open(file_path, 'r', encoding='utf-8') as file:
    html_content = file.read()

# Define the regex pattern
pattern = r'<a href="(/matchcentre/\d+-scorecard)"'

# Find all matches
matches4 = re.findall(pattern, html_content)
matches4
# Out:
# ['/matchcentre/241-scorecard',
#  '/matchcentre/240-scorecard',
#  '/matchcentre/239-scorecard',
#  '/matchcentre/238-scorecard',
#  '/matchcentre/237-scorecard',
#  '/matchcentre/236-scorecard',
#  '/matchcentre/235-scorecard',
#  '/matchcentre/234-scorecard',
#  '/matchcentre/233-scorecard',
#  '/matchcentre/232-scorecard',
#  '/matchcentre/231-scorecard',
#  '/matchcentre/230-scorecard',
#  '/matchcentre/229-scorecard',
#  '/matchcentre/228-scorecard',
#  '/matchcentre/227-scorecard',
#  '/matchcentre/226-scorecard',
#  '/matchcentre/225-scorecard',
#  '/matchcentre/224-scorecard',
#  '/matchcentre/223-scorecard',
#  '/matchcentre/222-scorecard',
#  '/matchcentre/221-scorecard',
#  '/matchcentre/220-scorecard',
#  '/matchcentre/219-scorecard',
#  '/matchcentre/218-scorecard',
#  '/matchcentre/217-scorecard',
#  '/matchcentre/216-scorecard',
#  '/matchcentre/215-scorecard',
#  '/matchcentre/214-scorecard',
#  '/matchcentre/213-scorecard',
#  '/matchcentre/212-scorecard',
# ...

# %%
# Path to local HTML file
file_path = r"C:\Users\KIIT\Downloads\season3.html"

# Read the HTML file
with open(file_path, 'r', encoding='utf-8') as file:
    html_content = file.read()

# Define the regex pattern
pattern = r'<a href="(/matchcentre/\d+-scorecard)"'

# Find all matches
matches3 = re.findall(pattern, html_content)
matches3
# Out:
# ['/matchcentre/181-scorecard',
#  '/matchcentre/180-scorecard',
#  '/matchcentre/179-scorecard',
#  '/matchcentre/178-scorecard',
#  '/matchcentre/177-scorecard',
#  '/matchcentre/176-scorecard',
#  '/matchcentre/175-scorecard',
#  '/matchcentre/174-scorecard',
#  '/matchcentre/173-scorecard',
#  '/matchcentre/172-scorecard',
#  '/matchcentre/171-scorecard',
#  '/matchcentre/170-scorecard',
#  '/matchcentre/169-scorecard',
#  '/matchcentre/168-scorecard',
#  '/matchcentre/167-scorecard',
#  '/matchcentre/166-scorecard',
#  '/matchcentre/165-scorecard',
#  '/matchcentre/164-scorecard',
#  '/matchcentre/163-scorecard',
#  '/matchcentre/162-scorecard',
#  '/matchcentre/161-scorecard',
#  '/matchcentre/160-scorecard',
#  '/matchcentre/159-scorecard',
#  '/matchcentre/158-scorecard',
#  '/matchcentre/157-scorecard',
#  '/matchcentre/156-scorecard',
#  '/matchcentre/155-scorecard',
#  '/matchcentre/154-scorecard',
#  '/matchcentre/153-scorecard',
#  '/matchcentre/152-scorecard',
# ...

# %%
# Path to local HTML file
file_path = r"C:\Users\KIIT\Downloads\season2.html"

# Read the HTML file
with open(file_path, 'r', encoding='utf-8') as file:
    html_content = file.read()

# Define the regex pattern
pattern = r'<a href="(/matchcentre/\d+-scorecard)"'

# Find all matches
matches2 = re.findall(pattern, html_content)
matches2
# Out:
# ['/matchcentre/121-scorecard',
#  '/matchcentre/120-scorecard',
#  '/matchcentre/119-scorecard',
#  '/matchcentre/118-scorecard',
#  '/matchcentre/117-scorecard',
#  '/matchcentre/116-scorecard',
#  '/matchcentre/115-scorecard',
#  '/matchcentre/114-scorecard',
#  '/matchcentre/113-scorecard',
#  '/matchcentre/112-scorecard',
#  '/matchcentre/111-scorecard',
#  '/matchcentre/110-scorecard',
#  '/matchcentre/109-scorecard',
#  '/matchcentre/108-scorecard',
#  '/matchcentre/107-scorecard',
#  '/matchcentre/106-scorecard',
#  '/matchcentre/105-scorecard',
#  '/matchcentre/104-scorecard',
#  '/matchcentre/103-scorecard',
#  '/matchcentre/102-scorecard',
#  '/matchcentre/101-scorecard',
#  '/matchcentre/100-scorecard',
#  '/matchcentre/99-scorecard',
#  '/matchcentre/98-scorecard',
#  '/matchcentre/97-scorecard',
#  '/matchcentre/96-scorecard',
#  '/matchcentre/95-scorecard',
#  '/matchcentre/94-scorecard',
#  '/matchcentre/93-scorecard',
#  '/matchcentre/92-scorecard',
# ...

# %%
# Path to local HTML file
file_path = r"C:\Users\KIIT\Downloads\season1.html"

# Read the HTML file
with open(file_path, 'r', encoding='utf-8') as file:
    html_content = file.read()

# Define the regex pattern
pattern = r'<a href="(/matchcentre/\d+-scorecard)"'

# Find all matches
matches1 = re.findall(pattern, html_content)
matches1
# Out:
# ['/matchcentre/60-scorecard',
#  '/matchcentre/59-scorecard',
#  '/matchcentre/58-scorecard',
#  '/matchcentre/57-scorecard',
#  '/matchcentre/56-scorecard',
#  '/matchcentre/55-scorecard',
#  '/matchcentre/54-scorecard',
#  '/matchcentre/53-scorecard',
#  '/matchcentre/52-scorecard',
#  '/matchcentre/51-scorecard',
#  '/matchcentre/50-scorecard',
#  '/matchcentre/49-scorecard',
#  '/matchcentre/48-scorecard',
#  '/matchcentre/47-scorecard',
#  '/matchcentre/46-scorecard',
#  '/matchcentre/45-scorecard',
#  '/matchcentre/44-scorecard',
#  '/matchcentre/43-scorecard',
#  '/matchcentre/42-scorecard',
#  '/matchcentre/41-scorecard',
#  '/matchcentre/40-scorecard',
#  '/matchcentre/39-scorecard',
#  '/matchcentre/38-scorecard',
#  '/matchcentre/37-scorecard',
#  '/matchcentre/36-scorecard',
#  '/matchcentre/35-scorecard',
#  '/matchcentre/34-scorecard',
#  '/matchcentre/33-scorecard',
#  '/matchcentre/32-scorecard',
#  '/matchcentre/31-scorecard',
#  '/matchcentre/30-scorecard',
# ...

# %%
def extract_json_from_script(script_content):
    start = script_content.find("window.scorecardWidgetData = ")
    if start == -1:
        return None
    start += len("window.scorecardWidgetData = ")

    bracket_count = 0
    end = start
    for i, char in enumerate(script_content[start:]):
        if char == "{":
            bracket_count += 1
        elif char == "}":
            bracket_count -= 1
            if bracket_count == 0:
                end = start + i + 1
                break

    if bracket_count != 0:
        return None

    json_str = script_content[start:end]

    try:
        return json.loads(json_str)
    except json.JSONDecodeError:
        return None

# %%
import pandas as pd
from bs4 import BeautifulSoup
import os
from selenium import webdriver


def fetch_and_process_data(url):
    options = webdriver.FirefoxOptions()
    options.add_argument("--headless")
    driver = webdriver.Firefox(options=options)

    try:
        driver.get(url)

        # Extract the script content
        soup = BeautifulSoup(driver.page_source)
        # print(soup)
        script_tag = soup.find(
            "script", string=lambda text: text and "window.scorecardWidgetData" in text
        )

        # if script_tag:
        #     json_data = extract_json_from_script(script_tag.string)
        #     with open('data.json', 'w') as json_file:
        #         json.dump(json_data, json_file, indent=4)
        # 
        #     print("JSON data saved to data.json")
        if script_tag:
            json_data = extract_json_from_script(script_tag.string)
            
            # Extract match ID from the URL
            match_id = url.split('/')[-1].split('-')[0]
            
            # Create a directory to store JSON files if it doesn't exist
            os.makedirs('match_data', exist_ok=True)
            
            # Save JSON data with a unique filename
            filename = f'match_data/match_{match_id}.json'
            with open(filename, 'w') as json_file:
                json.dump(json_data, json_file, indent=4)

            print(f"JSON data saved to {filename}")

    finally:
        driver.quit()

    return None

# %%
base_url = "https://www.prokabaddi.com"

# %%
for link in matches7:
    full_url = base_url + link
    print(f"Processing: {full_url}")
    fetch_and_process_data(full_url)
# Out:
# Processing: https://www.prokabaddi.com/matchcentre/1821-scorecard
# JSON data saved to match_data/match_1821.json
# Processing: https://www.prokabaddi.com/matchcentre/1820-scorecard
# JSON data saved to match_data/match_1820.json
# Processing: https://www.prokabaddi.com/matchcentre/1819-scorecard
# JSON data saved to match_data/match_1819.json
# Processing: https://www.prokabaddi.com/matchcentre/1818-scorecard
# JSON data saved to match_data/match_1818.json
# Processing: https://www.prokabaddi.com/matchcentre/1817-scorecard
# JSON data saved to match_data/match_1817.json
# Processing: https://www.prokabaddi.com/matchcentre/1816-scorecard
# JSON data saved to match_data/match_1816.json
# Processing: https://www.prokabaddi.com/matchcentre/1815-scorecard
# JSON data saved to match_data/match_1815.json
# Processing: https://www.prokabaddi.com/matchcentre/1814-scorecard
# JSON data saved to match_data/match_1814.json
# Processing: https://www.prokabaddi.com/matchcentre/1813-scorecard
# ...

# %%
for link in matches6:
    full_url = base_url + link
    print(f"Processing: {full_url}")
    fetch_and_process_data(full_url)
# Out:
# Processing: https://www.prokabaddi.com/matchcentre/762-scorecard
# JSON data saved to match_data/match_762.json
# Processing: https://www.prokabaddi.com/matchcentre/761-scorecard
# JSON data saved to match_data/match_761.json
# Processing: https://www.prokabaddi.com/matchcentre/760-scorecard
# JSON data saved to match_data/match_760.json
# Processing: https://www.prokabaddi.com/matchcentre/759-scorecard
# JSON data saved to match_data/match_759.json
# Processing: https://www.prokabaddi.com/matchcentre/758-scorecard
# JSON data saved to match_data/match_758.json
# Processing: https://www.prokabaddi.com/matchcentre/757-scorecard
# JSON data saved to match_data/match_757.json
# Processing: https://www.prokabaddi.com/matchcentre/756-scorecard
# JSON data saved to match_data/match_756.json
# Processing: https://www.prokabaddi.com/matchcentre/755-scorecard
# JSON data saved to match_data/match_755.json
# Processing: https://www.prokabaddi.com/matchcentre/754-scorecard
# ...

# %%
for link in matches5:
    full_url = base_url + link
    print(f"Processing: {full_url}")
    fetch_and_process_data(full_url)
# Out:
# Processing: https://www.prokabaddi.com/matchcentre/423-scorecard
# JSON data saved to match_data/match_423.json
# Processing: https://www.prokabaddi.com/matchcentre/422-scorecard
# JSON data saved to match_data/match_422.json
# Processing: https://www.prokabaddi.com/matchcentre/421-scorecard
# JSON data saved to match_data/match_421.json
# Processing: https://www.prokabaddi.com/matchcentre/420-scorecard
# JSON data saved to match_data/match_420.json
# Processing: https://www.prokabaddi.com/matchcentre/419-scorecard
# JSON data saved to match_data/match_419.json
# Processing: https://www.prokabaddi.com/matchcentre/418-scorecard
# JSON data saved to match_data/match_418.json
# Processing: https://www.prokabaddi.com/matchcentre/417-scorecard
# JSON data saved to match_data/match_417.json
# Processing: https://www.prokabaddi.com/matchcentre/416-scorecard
# JSON data saved to match_data/match_416.json
# Processing: https://www.prokabaddi.com/matchcentre/415-scorecard
# ...

# %%
for link in matches4:
    full_url = base_url + link
    print(f"Processing: {full_url}")
    fetch_and_process_data(full_url)
# Out:
# Processing: https://www.prokabaddi.com/matchcentre/241-scorecard
# JSON data saved to match_data/match_241.json
# Processing: https://www.prokabaddi.com/matchcentre/240-scorecard
# JSON data saved to match_data/match_240.json
# Processing: https://www.prokabaddi.com/matchcentre/239-scorecard
# JSON data saved to match_data/match_239.json
# Processing: https://www.prokabaddi.com/matchcentre/238-scorecard
# JSON data saved to match_data/match_238.json
# Processing: https://www.prokabaddi.com/matchcentre/237-scorecard
# JSON data saved to match_data/match_237.json
# Processing: https://www.prokabaddi.com/matchcentre/236-scorecard
# JSON data saved to match_data/match_236.json
# Processing: https://www.prokabaddi.com/matchcentre/235-scorecard
# JSON data saved to match_data/match_235.json
# Processing: https://www.prokabaddi.com/matchcentre/234-scorecard
# JSON data saved to match_data/match_234.json
# Processing: https://www.prokabaddi.com/matchcentre/233-scorecard
# ...

# %%
for link in matches3:
    full_url = base_url + link
    print(f"Processing: {full_url}")
    fetch_and_process_data(full_url)
# Out:
# Processing: https://www.prokabaddi.com/matchcentre/181-scorecard
# JSON data saved to match_data/match_181.json
# Processing: https://www.prokabaddi.com/matchcentre/180-scorecard
# JSON data saved to match_data/match_180.json
# Processing: https://www.prokabaddi.com/matchcentre/179-scorecard
# JSON data saved to match_data/match_179.json
# Processing: https://www.prokabaddi.com/matchcentre/178-scorecard
# JSON data saved to match_data/match_178.json
# Processing: https://www.prokabaddi.com/matchcentre/177-scorecard
# JSON data saved to match_data/match_177.json
# Processing: https://www.prokabaddi.com/matchcentre/176-scorecard
# JSON data saved to match_data/match_176.json
# Processing: https://www.prokabaddi.com/matchcentre/175-scorecard
# JSON data saved to match_data/match_175.json
# Processing: https://www.prokabaddi.com/matchcentre/174-scorecard
# JSON data saved to match_data/match_174.json
# Processing: https://www.prokabaddi.com/matchcentre/173-scorecard
# ...

# %%
for link in matches2:
    full_url = base_url + link
    print(f"Processing: {full_url}")
    fetch_and_process_data(full_url)
# Out:
# Processing: https://www.prokabaddi.com/matchcentre/121-scorecard
# JSON data saved to match_data/match_121.json
# Processing: https://www.prokabaddi.com/matchcentre/120-scorecard
# JSON data saved to match_data/match_120.json
# Processing: https://www.prokabaddi.com/matchcentre/119-scorecard
# JSON data saved to match_data/match_119.json
# Processing: https://www.prokabaddi.com/matchcentre/118-scorecard
# JSON data saved to match_data/match_118.json
# Processing: https://www.prokabaddi.com/matchcentre/117-scorecard
# JSON data saved to match_data/match_117.json
# Processing: https://www.prokabaddi.com/matchcentre/116-scorecard
# JSON data saved to match_data/match_116.json
# Processing: https://www.prokabaddi.com/matchcentre/115-scorecard
# JSON data saved to match_data/match_115.json
# Processing: https://www.prokabaddi.com/matchcentre/114-scorecard
# JSON data saved to match_data/match_114.json
# Processing: https://www.prokabaddi.com/matchcentre/113-scorecard
# ...

# %%
for link in matches1:
    full_url = base_url + link
    print(f"Processing: {full_url}")
    fetch_and_process_data(full_url)
# Out:
# Processing: https://www.prokabaddi.com/matchcentre/60-scorecard
# JSON data saved to match_data/match_60.json
# Processing: https://www.prokabaddi.com/matchcentre/59-scorecard
# JSON data saved to match_data/match_59.json
# Processing: https://www.prokabaddi.com/matchcentre/58-scorecard
# JSON data saved to match_data/match_58.json
# Processing: https://www.prokabaddi.com/matchcentre/57-scorecard
# JSON data saved to match_data/match_57.json
# Processing: https://www.prokabaddi.com/matchcentre/56-scorecard
# JSON data saved to match_data/match_56.json
# Processing: https://www.prokabaddi.com/matchcentre/55-scorecard
# JSON data saved to match_data/match_55.json
# Processing: https://www.prokabaddi.com/matchcentre/54-scorecard
# JSON data saved to match_data/match_54.json
# Processing: https://www.prokabaddi.com/matchcentre/53-scorecard
# JSON data saved to match_data/match_53.json
# Processing: https://www.prokabaddi.com/matchcentre/52-scorecard
# ...

# %%
print("hello")
# Out:
# hello

# %%
import os

directory = '../correct_scraping_scripts/match_data'

# Loop through each file in the directory
for filename in os.listdir(directory):
    if filename.startswith("match_") and filename.endswith(".json"):
        # Extract the match ID
        match_id = filename.split("match_")[1]
        
        # Define the new filename
        new_filename = f"{match_id}"
        
        # Get the full paths for the old and new filenames
        old_file = os.path.join(directory, filename)
        new_file = os.path.join(directory, new_filename)
        
        # Rename the file
        os.rename(old_file, new_file)

print("Files have been renamed successfully.")
# Out:
# Files have been renamed successfully.
